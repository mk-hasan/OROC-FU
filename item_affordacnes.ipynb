# %%
import pandas as pd

# %%
data_aff = pd.read_csv('/home/hasan/Downloads/item_affordances.csv')

# %%
data_aff.head()
# Out:
#                             HITId                       HITTypeId  \
# 0  37NXA7GVSUJBU2XQYM2SVK13I3HVLZ  3UY9ZAUDME5BR52BHJHDKDGHLYFALG
# 1  37NXA7GVSUJBU2XQYM2SVK13I3HVLZ  3UY9ZAUDME5BR52BHJHDKDGHLYFALG
# 2  37NXA7GVSUJBU2XQYM2SVK13I3HVLZ  3UY9ZAUDME5BR52BHJHDKDGHLYFALG
# 3  37NXA7GVSUJBU2XQYM2SVK13I3HVLZ  3UY9ZAUDME5BR52BHJHDKDGHLYFALG
# 4  37NXA7GVSUJBU2XQYM2SVK13I3HVLZ  3UY9ZAUDME5BR52BHJHDKDGHLYFALG
#
#                                                Title  \
# 0  What is the novelty,likability and usability o...
# 1  What is the novelty,likability and usability o...
# 2  What is the novelty,likability and usability o...
# 3  What is the novelty,likability and usability o...
# 4  What is the novelty,likability and usability o...
#
#                                          Description  \
# 0  In this task you will answer what is the level...
# 1  In this task you will answer what is the level...
# 2  In this task you will answer what is the level...
# 3  In this task you will answer what is the level...
# 4  In this task you will answer what is the level...
#
#                      Keywords Reward                  CreationTime  \
# 0  item, equality, comparison  $0.02  Wed Jun 19 07:20:55 PDT 2019
# 1  item, equality, comparison  $0.02  Wed Jun 19 07:20:55 PDT 2019
# 2  item, equality, comparison  $0.02  Wed Jun 19 07:20:55 PDT 2019
# 3  item, equality, comparison  $0.02  Wed Jun 19 07:20:55 PDT 2019
# 4  item, equality, comparison  $0.02  Wed Jun 19 07:20:55 PDT 2019
#
#    MaxAssignments                               RequesterAnnotation  \
# 0               5  BatchId:3680734;OriginalHitTemplateId:928390889;
# 1               5  BatchId:3680734;OriginalHitTemplateId:928390889;
# 2               5  BatchId:3680734;OriginalHitTemplateId:928390889;
# 3               5  BatchId:3680734;OriginalHitTemplateId:928390889;
# 4               5  BatchId:3680734;OriginalHitTemplateId:928390889;
#
#    AssignmentDurationInSeconds  ...    LifetimeApprovalRate  \
# 0                         1200  ...                0% (0/0)
# 1                         1200  ...                0% (0/2)
# 2                         1200  ...                0% (0/0)
# 3                         1200  ...                0% (0/2)
# 4                         1200  ...                0% (0/0)
#
#   Last30DaysApprovalRate  Last7DaysApprovalRate  Input.original_language  \
# 0               0% (0/0)               0% (0/0)                      Cup
# 1               0% (0/2)               0% (0/2)                      Cup
# 2               0% (0/0)               0% (0/0)                      Cup
# 3               0% (0/2)               0% (0/2)                      Cup
# 4               0% (0/0)               0% (0/0)                      Cup
#
#   Input.original_text Answer.likeability Answer.novelty Answer.usability  \
# 0   as food container                  3              2                2
# 1   as food container                  6              1                7
# 2   as food container                  4              5                3
# 3   as food container                  5              4                7
# 4   as food container                  4              5                6
#
#   Approve Reject
# 0     NaN    NaN
# 1     NaN    NaN
# 2     NaN    NaN
# 3     NaN    NaN
# 4     NaN    NaN
#
# [5 rows x 34 columns]

# %%
data_f = data_aff.drop(['HITId','HITTypeId','Title','Description','Keywords','Reward','CreationTime','MaxAssignments','RequesterFeedback','WorkTimeInSeconds','LifetimeApprovalRate','Last30DaysApprovalRate','Last7DaysApprovalRate','Approve','Reject','RequesterAnnotation','AssignmentDurationInSeconds','AutoApprovalDelayInSeconds','Expiration','NumberOfSimilarHITs','LifetimeInSeconds','AssignmentId','WorkerId','AssignmentStatus','AcceptTime','SubmitTime','AutoApprovalTime','RejectionTime','ApprovalTime'],axis=1)

# %%
data_f.head()
# Out:
#   Input.original_language Input.original_text  Answer.likeability  \
# 0                     Cup   as food container                   3
# 1                     Cup   as food container                   6
# 2                     Cup   as food container                   4
# 3                     Cup   as food container                   5
# 4                     Cup   as food container                   4
#
#    Answer.novelty  Answer.usability
# 0               2                 2
# 1               1                 7
# 2               5                 3
# 3               4                 7
# 4               5                 6

# %%
data_f.rename(index=str, columns={"Input.original_language":"object","Input.original_text":"affordances","Answer.likeability"
:"likeability",'Answer.novelty':'novelty','Answer.usability':'usability'},inplace=True)

# %%
data_f.head()
# Out:
#   object        affordances  likeability  novelty  usability
# 0    Cup  as food container            3        2          2
# 1    Cup  as food container            6        1          7
# 2    Cup  as food container            4        5          3
# 3    Cup  as food container            5        4          7
# 4    Cup  as food container            4        5          6

# %%
data_f.to_csv(r'/home/hasan/Documents/BitRepos/orocv2/Object_affordance.csv')

# %%
aff_mean = data_f.groupby('object').mean()
aff_sd = data_f.groupby('object').std()

# %%
aff_mean.head()
# Out:
#                 likeability  novelty  usability          object
# object
# Ashtray                 1.8      2.6        2.4         Ashtray
# Bathroom Towel          3.6      4.0        6.0  Bathroom Towel
# Blanket                 3.0      2.6        4.0         Blanket
# Book                    7.0      3.8        7.0            Book
# Bottle                  7.0      3.6        7.0          Bottle

# %%
total_mean=aff_mean.mean()
total_mean
# Out:
# likeability    3.307905
# novelty        3.892190
# usability      4.011905
# dtype: float64

# %%
total_sd=aff_sd.mean()
total_sd
# Out:
# likeability    1.336915
# novelty        1.936638
# usability      1.417395
# dtype: float64

# %%
aff_mean
# Out:
#                 likeability   novelty  usability          object
# object
# Ashtray            1.800000  2.600000   2.400000         Ashtray
# Bathroom Towel     3.600000  4.000000   6.000000  Bathroom Towel
# Blanket            3.000000  2.600000   4.000000         Blanket
# Book               7.000000  3.800000   7.000000            Book
# Bottle             7.000000  3.600000   7.000000          Bottle
# Bowl               6.600000  1.600000   7.000000            Bowl
# Broom              1.200000  2.200000   1.400000           Broom
# Can                5.000000  3.000000   6.000000             Can
# Can opener         1.200000  2.800000   1.400000      Can opener
# Candle Holder      4.800000  5.400000   5.600000   Candle Holder
# Clothesline        1.600000  4.400000   1.400000     Clothesline
# Coat brush         2.200000  4.200000   3.000000      Coat brush
# Container          3.800000  3.400000   6.200000       Container
# Cup                4.400000  3.400000   5.000000             Cup
# Curtain            3.600000  4.400000   4.200000         Curtain
# Desk               4.200000  3.600000   5.200000            Desk
# Doormat            2.400000  5.200000   2.800000         Doormat
# Flowerpot          3.200000  5.800000   4.000000       Flowerpot
# Hammer             3.400000  4.200000   5.000000          Hammer
# Jar                3.000000  4.200000   4.000000             Jar
# Kitchen Towel      2.600000  2.800000   5.000000   Kitchen Towel
# Lid                4.200000  4.400000   5.000000             Lid
# Matchbox           2.200000  4.800000   1.600000        Matchbox
# Nail               3.200000  5.000000   3.600000            Nail
# Newspaper          5.800000  4.000000   6.800000       Newspaper
# Painting brush     1.600000  5.200000   1.600000  Painting brush
# Pan                3.600000  4.000000   4.200000             Pan
# PaperTowel         2.800000  3.200000   3.400000      PaperTowel
# Pillow             3.800000  3.800000   2.000000          Pillow
# Pillow case        2.800000  5.000000   3.400000     Pillow case
# Plate              3.400000  4.600000   3.200000           Plate
# Pot                4.000000  3.000000   5.600000             Pot
# Rug                1.600000  5.000000   2.200000             Rug
# Saucer             3.000000  2.400000   5.800000          Saucer
# Scales             2.600000  4.000000   3.600000          Scales
# Sheet              3.666667  3.666667   4.833333           Sheet
# Sheet of Paper     2.000000  3.200000   3.200000  Sheet of Paper
# Shelf              5.600000  3.800000   6.000000           Shelf
# Shoe brush         1.600000  5.200000   2.200000      Shoe brush
# Soap               1.400000  4.600000   2.000000            Soap
# Sofa Cover         2.800000  3.600000   3.600000      Sofa Cover
# Spoon              2.800000  2.800000   3.600000           Spoon
# Surfboard          1.800000  4.600000   2.000000       Surfboard
# Table              4.500000  3.000000   6.333333           Table
# Toilet brush       1.600000  4.800000   1.800000    Toilet brush
# Toothbrush         2.200000  4.000000   2.600000      Toothbrush
# Towel              5.428571  3.142857   6.428571           Towel
# Umbrella           1.000000  4.600000   1.200000        Umbrella
# Vase               5.600000  3.000000   6.200000            Vase
# Wallpaper          3.200000  5.000000   3.000000       Wallpaper

# %%
aff_sd
# Out:
#                 likeability   novelty  usability          object
# object
# Ashtray            1.788854  1.816590   1.516575         Ashtray
# Bathroom Towel     1.816590  0.707107   1.732051  Bathroom Towel
# Blanket            1.581139  0.894427   1.870829         Blanket
# Book               0.000000  2.949576   0.000000            Book
# Bottle             0.000000  3.130495   0.000000          Bottle
# Bowl               0.894427  0.547723   0.000000            Bowl
# Broom              0.447214  1.303840   0.547723           Broom
# Can                1.581139  1.224745   1.224745             Can
# Can opener         0.447214  2.489980   0.547723      Can opener
# Candle Holder      1.923538  1.140175   1.341641   Candle Holder
# Clothesline        0.894427  2.701851   0.547723     Clothesline
# Coat brush         1.095445  2.588436   1.000000      Coat brush
# Container          2.049390  2.073644   1.095445       Container
# Cup                1.140175  1.816590   2.345208             Cup
# Curtain            2.073644  2.701851   2.167948         Curtain
# Desk               0.447214  1.516575   0.836660            Desk
# Doormat            1.140175  2.049390   1.923538         Doormat
# Flowerpot          1.643168  2.167948   1.870829       Flowerpot
# Hammer             1.673320  1.643168   2.121320          Hammer
# Jar                1.000000  1.303840   2.345208             Jar
# Kitchen Towel      0.894427  0.836660   2.345208   Kitchen Towel
# Lid                2.167948  1.816590   2.121320             Lid
# Matchbox           0.836660  2.489980   0.547723        Matchbox
# Nail               2.683282  1.224745   2.701851            Nail
# Newspaper          1.643168  2.828427   0.447214       Newspaper
# Painting brush     0.894427  1.303840   0.547723  Painting brush
# Pan                1.673320  1.581139   1.095445             Pan
# PaperTowel         1.923538  0.836660   2.302173      PaperTowel
# Pillow             1.923538  2.489980   0.707107          Pillow
# Pillow case        1.095445  1.581139   1.341641     Pillow case
# Plate              1.816590  2.190890   2.167948           Plate
# Pot                2.000000  2.345208   2.607681             Pot
# Rug                0.894427  2.000000   1.303840             Rug
# Saucer             2.000000  0.894427   1.303840          Saucer
# Scales             1.341641  2.345208   1.673320          Scales
# Sheet              1.861899  2.338090   2.136976           Sheet
# Sheet of Paper     0.707107  1.303840   1.303840  Sheet of Paper
# Shelf              1.341641  2.049390   1.224745           Shelf
# Shoe brush         0.547723  2.683282   1.643168      Shoe brush
# Soap               0.547723  2.607681   1.732051            Soap
# Sofa Cover         2.167948  2.302173   1.949359      Sofa Cover
# Spoon              1.095445  1.483240   1.516575           Spoon
# Surfboard          1.303840  2.190890   1.732051       Surfboard
# Table              2.258318  2.190890   0.816497           Table
# Toilet brush       0.894427  2.489980   0.447214    Toilet brush
# Toothbrush         1.303840  2.828427   2.509980      Toothbrush
# Towel              1.812654  2.544836   1.511858           Towel
# Umbrella           0.000000  3.286335   0.447214        Umbrella
# Vase               0.894427  2.000000   1.303840            Vase
# Wallpaper          2.683282  1.000000   2.345208       Wallpaper

# %%
aff_mean.head()
aff_mean['object'] = aff_mean.index
aff_sd['object'] = aff_sd.index

# %%
aff_mean.plot(figsize=(15,5),x='object',y='novelty',kind='bar',title="Mean Novelty")

# %%
aff_mean.plot(figsize=(15,5),x='object',y='likeability',kind='bar',title="Mean Likability")

# %%
aff_mean.plot(figsize=(15,5),x='object',y='usability',kind='bar',title="Mean Usefulness")

# %%
aff_mean.plot(figsize=(15,5),x='object',y=['usability','usability','novelty'],kind='bar',title="Ratings per object group")
