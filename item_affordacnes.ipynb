# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
data_aff = pd.read_csv('/home/hasan/Documents/BitRepos/orocv2/item_affordances.csv')

# %%
data_aff.head()
# Out:
#                             HITId                       HITTypeId  \
# 0  37NXA7GVSUJBU2XQYM2SVK13I3HVLZ  3UY9ZAUDME5BR52BHJHDKDGHLYFALG
# 1  37NXA7GVSUJBU2XQYM2SVK13I3HVLZ  3UY9ZAUDME5BR52BHJHDKDGHLYFALG
# 2  37NXA7GVSUJBU2XQYM2SVK13I3HVLZ  3UY9ZAUDME5BR52BHJHDKDGHLYFALG
# 3  37NXA7GVSUJBU2XQYM2SVK13I3HVLZ  3UY9ZAUDME5BR52BHJHDKDGHLYFALG
# 4  37NXA7GVSUJBU2XQYM2SVK13I3HVLZ  3UY9ZAUDME5BR52BHJHDKDGHLYFALG
#
#                                                Title  \
# 0  What is the novelty,likability and usability o...
# 1  What is the novelty,likability and usability o...
# 2  What is the novelty,likability and usability o...
# 3  What is the novelty,likability and usability o...
# 4  What is the novelty,likability and usability o...
#
#                                          Description  \
# 0  In this task you will answer what is the level...
# 1  In this task you will answer what is the level...
# 2  In this task you will answer what is the level...
# 3  In this task you will answer what is the level...
# 4  In this task you will answer what is the level...
#
#                      Keywords Reward                  CreationTime  \
# 0  item, equality, comparison  $0.02  Wed Jun 19 07:20:55 PDT 2019
# 1  item, equality, comparison  $0.02  Wed Jun 19 07:20:55 PDT 2019
# 2  item, equality, comparison  $0.02  Wed Jun 19 07:20:55 PDT 2019
# 3  item, equality, comparison  $0.02  Wed Jun 19 07:20:55 PDT 2019
# 4  item, equality, comparison  $0.02  Wed Jun 19 07:20:55 PDT 2019
#
#    MaxAssignments                               RequesterAnnotation  \
# 0               5  BatchId:3680734;OriginalHitTemplateId:928390889;
# 1               5  BatchId:3680734;OriginalHitTemplateId:928390889;
# 2               5  BatchId:3680734;OriginalHitTemplateId:928390889;
# 3               5  BatchId:3680734;OriginalHitTemplateId:928390889;
# 4               5  BatchId:3680734;OriginalHitTemplateId:928390889;
#
#    AssignmentDurationInSeconds  ...    LifetimeApprovalRate  \
# 0                         1200  ...                0% (0/0)
# 1                         1200  ...                0% (0/2)
# 2                         1200  ...                0% (0/0)
# 3                         1200  ...                0% (0/2)
# 4                         1200  ...                0% (0/0)
#
#   Last30DaysApprovalRate  Last7DaysApprovalRate  Input.original_language  \
# 0               0% (0/0)               0% (0/0)                      Cup
# 1               0% (0/2)               0% (0/2)                      Cup
# 2               0% (0/0)               0% (0/0)                      Cup
# 3               0% (0/2)               0% (0/2)                      Cup
# 4               0% (0/0)               0% (0/0)                      Cup
#
#   Input.original_text Answer.likeability Answer.novelty Answer.usability  \
# 0   as food container                  3              2                2
# 1   as food container                  6              1                7
# 2   as food container                  4              5                3
# 3   as food container                  5              4                7
# 4   as food container                  4              5                6
#
#   Approve Reject
# 0     NaN    NaN
# 1     NaN    NaN
# 2     NaN    NaN
# 3     NaN    NaN
# 4     NaN    NaN
#
# [5 rows x 34 columns]

# %%
data_f = data_aff.drop(['HITId','HITTypeId','Title','Description','Keywords','Reward','CreationTime','MaxAssignments','RequesterFeedback','WorkTimeInSeconds','LifetimeApprovalRate','Last30DaysApprovalRate','Last7DaysApprovalRate','Approve','Reject','RequesterAnnotation','AssignmentDurationInSeconds','AutoApprovalDelayInSeconds','Expiration','NumberOfSimilarHITs','LifetimeInSeconds','AssignmentId','AssignmentStatus','AcceptTime','SubmitTime','AutoApprovalTime','RejectionTime','ApprovalTime'],axis=1)

# %%
data_f.head()
# Out:
#          WorkerId Input.original_language Input.original_text  \
# 0  A2GKX7OV3D8A3T                     Cup   as food container
# 1  A14MCHQB6Z8MVT                     Cup   as food container
# 2   ABMH09TPJ72JW                     Cup   as food container
# 3  A30OWLTYVF4Y79                     Cup   as food container
# 4  A1C4LNTWGUOD4P                     Cup   as food container
#
#    Answer.likeability  Answer.novelty  Answer.usability
# 0                   3               2                 2
# 1                   6               1                 7
# 2                   4               5                 3
# 3                   5               4                 7
# 4                   4               5                 6

# %%
data_f.rename(index=str, columns={"Input.original_language":"object","Input.original_text":"affordances","Answer.likeability"
:"likeability",'Answer.novelty':'novelty','Answer.usability':'usability'},inplace=True)

# %%
data_f.head()
# Out:
#          WorkerId object        affordances  likeability  novelty  usability
# 0  A2GKX7OV3D8A3T    Cup  as food container            3        2          2
# 1  A14MCHQB6Z8MVT    Cup  as food container            6        1          7
# 2   ABMH09TPJ72JW    Cup  as food container            4        5          3
# 3  A30OWLTYVF4Y79    Cup  as food container            5        4          7
# 4  A1C4LNTWGUOD4P    Cup  as food container            4        5          6

# %%
def detect_outlier(data_1):
    outliers=[]
    #print(data_1)
    threshold=2
    mean_1 = np.mean(data_1)
    std_1 =np.std(data_1)  
    for y in data_1:
        z_score= (y - mean_1)/std_1 
        #print(np.abs(z_score))
        if np.abs(z_score) >= threshold:
            outliers.append(y)
    return outliers

# %%
def percentile_20(x):
    q1=x.quantile(0.2)
    q3=x.quantile(0.8)
    x =x.values.tolist()
    f_val=detect_outlier(x)
    return f_val

# %%
def same_number(df):
    #print(df)
    if(len(set(df))==1):
        return 1
    else:
        return 0

# %%
data_outlier=data_f.groupby(by="object", as_index=False, sort=False)["usability"].agg([percentile_20])

data_outlier_same= data_f.groupby(by="WorkerId", as_index=False, sort=False)["usability"].agg([same_number])
# Out:
# /home/hasan/anaconda3/envs/BD/lib/python3.6/site-packages/ipykernel_launcher.py:8: RuntimeWarning: invalid value encountered in double_scalars

# %%
data_outlier_same
# Out:
#                 same_number
# WorkerId
# A2GKX7OV3D8A3T            0
# A14MCHQB6Z8MVT            0
# ABMH09TPJ72JW             0
# A30OWLTYVF4Y79            0
# A1C4LNTWGUOD4P            0
# A1IQC2Y3UN3WEN            0
# A2SN4E7PX1NCLY            0
# A3A6C8329VTSN7            0
# A3T9WZOUQGE2UW            0
# A3LLAS4WXA8SKJ            0
# A1RYSM4DVE5VPZ            0
# AWWR9PY50W0Z9             0
# A21NED23NSZLLD            0
# ATFI0R8PVG76L             0
# APQTHI7VUXG2E             1
# A10P06DG75N0Z1            0
# A3B4TT66MBD4GQ            0
# A35C0II2FFV18S            0
# A2ON0WJ2MVI288            1
# AKKBFTQKC0D8H             0
# A1AMGHYG5PT0L2            0
# A1MTOAVJOWQS0M            1
# A24DSECWUBZC0Z            1
# A24NYP336X0LCJ            1
# A1XHFQKX09Y1RD            1
# AO2M8J1H30OZF             1
# A5E2P5F1AXYZ1             0
# AJ9O2ZA0E8UDZ             0
# A3PIDY15ODYS8             1
# A3EUFDOUX1GCL             0
# ATT3WMHDZNE0F             1
# A2EELTS09HUTSF            0
# AN6L87Z4LP6R5             1
# AD07S29ZUGNAK             1
# A20W9ZCV1YTGEM            1
# A2QV1T88XD5J7F            1

# %%
data_f.to_csv(r'/home/hasan/Documents/BitRepos/orocv2/Object_affordance.csv')

# %%
aff_mean = data_f.groupby('object').mean().reset_index()
aff_sd = data_f.groupby('object').std().reset_index()

# %%
aff_mean.head()
# Out:
#            object  likeability  novelty  usability
# 0         Ashtray          1.8      2.6        2.4
# 1  Bathroom Towel          3.6      4.0        6.0
# 2         Blanket          3.0      2.6        4.0
# 3            Book          7.0      3.8        7.0
# 4          Bottle          7.0      3.6        7.0

# %%
total_mean=aff_mean.mean().reset_index()
total_mean
# Out:
#          index         0
# 0  likeability  3.307905
# 1      novelty  3.892190
# 2    usability  4.011905

# %%
total_sd=aff_sd.mean().reset_index()
total_sd
# Out:
#          index         0
# 0  likeability  1.336915
# 1      novelty  1.936638
# 2    usability  1.417395

# %%
aff_mean
# Out:
#             object  likeability   novelty  usability
# 0          Ashtray     1.800000  2.600000   2.400000
# 1   Bathroom Towel     3.600000  4.000000   6.000000
# 2          Blanket     3.000000  2.600000   4.000000
# 3             Book     7.000000  3.800000   7.000000
# 4           Bottle     7.000000  3.600000   7.000000
# 5             Bowl     6.600000  1.600000   7.000000
# 6            Broom     1.200000  2.200000   1.400000
# 7              Can     5.000000  3.000000   6.000000
# 8       Can opener     1.200000  2.800000   1.400000
# 9    Candle Holder     4.800000  5.400000   5.600000
# 10     Clothesline     1.600000  4.400000   1.400000
# 11      Coat brush     2.200000  4.200000   3.000000
# 12       Container     3.800000  3.400000   6.200000
# 13             Cup     4.400000  3.400000   5.000000
# 14         Curtain     3.600000  4.400000   4.200000
# 15            Desk     4.200000  3.600000   5.200000
# 16         Doormat     2.400000  5.200000   2.800000
# 17       Flowerpot     3.200000  5.800000   4.000000
# 18          Hammer     3.400000  4.200000   5.000000
# 19             Jar     3.000000  4.200000   4.000000
# 20   Kitchen Towel     2.600000  2.800000   5.000000
# 21             Lid     4.200000  4.400000   5.000000
# 22        Matchbox     2.200000  4.800000   1.600000
# 23            Nail     3.200000  5.000000   3.600000
# 24       Newspaper     5.800000  4.000000   6.800000
# 25  Painting brush     1.600000  5.200000   1.600000
# 26             Pan     3.600000  4.000000   4.200000
# 27      PaperTowel     2.800000  3.200000   3.400000
# 28          Pillow     3.800000  3.800000   2.000000
# 29     Pillow case     2.800000  5.000000   3.400000
# 30           Plate     3.400000  4.600000   3.200000
# 31             Pot     4.000000  3.000000   5.600000
# 32             Rug     1.600000  5.000000   2.200000
# 33          Saucer     3.000000  2.400000   5.800000
# 34          Scales     2.600000  4.000000   3.600000
# 35           Sheet     3.666667  3.666667   4.833333
# 36  Sheet of Paper     2.000000  3.200000   3.200000
# 37           Shelf     5.600000  3.800000   6.000000
# 38      Shoe brush     1.600000  5.200000   2.200000
# 39            Soap     1.400000  4.600000   2.000000
# 40      Sofa Cover     2.800000  3.600000   3.600000
# 41           Spoon     2.800000  2.800000   3.600000
# 42       Surfboard     1.800000  4.600000   2.000000
# 43           Table     4.500000  3.000000   6.333333
# 44    Toilet brush     1.600000  4.800000   1.800000
# 45      Toothbrush     2.200000  4.000000   2.600000
# 46           Towel     5.428571  3.142857   6.428571
# 47        Umbrella     1.000000  4.600000   1.200000
# 48            Vase     5.600000  3.000000   6.200000
# 49       Wallpaper     3.200000  5.000000   3.000000

# %%
aff_sd
# Out:
#             object  likeability   novelty  usability
# 0          Ashtray     1.788854  1.816590   1.516575
# 1   Bathroom Towel     1.816590  0.707107   1.732051
# 2          Blanket     1.581139  0.894427   1.870829
# 3             Book     0.000000  2.949576   0.000000
# 4           Bottle     0.000000  3.130495   0.000000
# 5             Bowl     0.894427  0.547723   0.000000
# 6            Broom     0.447214  1.303840   0.547723
# 7              Can     1.581139  1.224745   1.224745
# 8       Can opener     0.447214  2.489980   0.547723
# 9    Candle Holder     1.923538  1.140175   1.341641
# 10     Clothesline     0.894427  2.701851   0.547723
# 11      Coat brush     1.095445  2.588436   1.000000
# 12       Container     2.049390  2.073644   1.095445
# 13             Cup     1.140175  1.816590   2.345208
# 14         Curtain     2.073644  2.701851   2.167948
# 15            Desk     0.447214  1.516575   0.836660
# 16         Doormat     1.140175  2.049390   1.923538
# 17       Flowerpot     1.643168  2.167948   1.870829
# 18          Hammer     1.673320  1.643168   2.121320
# 19             Jar     1.000000  1.303840   2.345208
# 20   Kitchen Towel     0.894427  0.836660   2.345208
# 21             Lid     2.167948  1.816590   2.121320
# 22        Matchbox     0.836660  2.489980   0.547723
# 23            Nail     2.683282  1.224745   2.701851
# 24       Newspaper     1.643168  2.828427   0.447214
# 25  Painting brush     0.894427  1.303840   0.547723
# 26             Pan     1.673320  1.581139   1.095445
# 27      PaperTowel     1.923538  0.836660   2.302173
# 28          Pillow     1.923538  2.489980   0.707107
# 29     Pillow case     1.095445  1.581139   1.341641
# 30           Plate     1.816590  2.190890   2.167948
# 31             Pot     2.000000  2.345208   2.607681
# 32             Rug     0.894427  2.000000   1.303840
# 33          Saucer     2.000000  0.894427   1.303840
# 34          Scales     1.341641  2.345208   1.673320
# 35           Sheet     1.861899  2.338090   2.136976
# 36  Sheet of Paper     0.707107  1.303840   1.303840
# 37           Shelf     1.341641  2.049390   1.224745
# 38      Shoe brush     0.547723  2.683282   1.643168
# 39            Soap     0.547723  2.607681   1.732051
# 40      Sofa Cover     2.167948  2.302173   1.949359
# 41           Spoon     1.095445  1.483240   1.516575
# 42       Surfboard     1.303840  2.190890   1.732051
# 43           Table     2.258318  2.190890   0.816497
# 44    Toilet brush     0.894427  2.489980   0.447214
# 45      Toothbrush     1.303840  2.828427   2.509980
# 46           Towel     1.812654  2.544836   1.511858
# 47        Umbrella     0.000000  3.286335   0.447214
# 48            Vase     0.894427  2.000000   1.303840
# 49       Wallpaper     2.683282  1.000000   2.345208

# %%
aff_mean.head()
aff_mean['object'] = aff_mean.index
aff_sd['object'] = aff_sd.index

# %%
aff_mean.plot(figsize=(15,5),x='object',y='novelty',kind='bar',title="Mean Novelty")

# %%
aff_mean.plot(figsize=(15,5),x='object',y='likeability',kind='bar',title="Mean Likability")

# %%
aff_mean.plot(figsize=(15,5),x='object',y='usability',kind='bar',title="Mean Usefulness")

# %%
aff_mean.plot(figsize=(15,5),x='object',y=['usability','usability','novelty'],kind='bar',title="Ratings per object group")
