# %%
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd

# %%
#load the data
dataset = pd.read_csv("/home/hasan/Downloads/meandev.csv")

# %%
dataset.head()
# Out:
#   material1  material2  mean     stdev
# 0  Adhesive   Adhesive   7.0  0.000000
# 1  Adhesive      Brick   1.6  0.894427
# 2  Adhesive  Cardboard   2.2  1.303840
# 3  Adhesive    Ceramic   1.4  0.894427
# 4  Adhesive      Cloth   1.6  0.894427

# %%
b=dataset.drop(dataset.columns[[0,1,3]],axis=1)

# %%
b
# Out:
#      mean
# 0     7.0
# 1     1.6
# 2     2.2
# 3     1.4
# 4     1.6
# 5     2.0
# 6     1.0
# 7     1.0
# 8     1.4
# 9     1.4
# 10    1.0
# 11    1.4
# 12    1.4
# 13    1.6
# 14    1.6
# 15    2.8
# 16    1.4
# 17    2.4
# 18    3.8
# 19    1.4
# 20    1.0
# 21    1.2
# 22    7.0
# 23    1.0
# 24    3.0
# 25    1.0
# 26    4.4
# 27    1.0
# 28    2.4
# 29    2.0
# ..    ...
# 411   3.6
# 412   1.6
# 413   1.4
# 414   1.8
# 415   2.6
# 416   1.0
# 417   1.4
# 418   7.0
# 419   1.0
# 420   1.4
# 421   1.0
# 422   1.2
# 423   1.6
# 424   5.8
# 425   1.0
# 426   5.2
# 427   1.4
# 428   1.2
# 429   3.2
# 430   1.2
# 431   2.2
# 432   1.6
# 433   1.6
# 434   1.0
# 435   2.6
# 436   1.0
# 437   2.0
# 438   1.6
# 439   1.4
# 440   7.0
#
# [441 rows x 1 columns]

# %%
b.shape
# Out:
# (441, 1)

# %%
b.reshape(20,20)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-54-9b202bb65263> in <module>
# ----> 1 b.reshape(20,20)
#
# ~/.local/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'reshape'

# %%
result=pd.DataFrame(np.reshape(b.values,(21,21)),columns=["Adhesive","Brick","Cardboard","Ceramic","Cloth","Concrete","Cotton","Diamond","Glass","Leather","Marble","Metal","Paper","Plastic","Porcelain","Rubber","Stone","Styrofoam","Wax","Wood","Wool"],index=["Adhesive","Brick","Cardboard","Ceramic","Cloth","Concrete","Cotton","Diamond","Glass","Leather","Marble","Metal","Paper","Plastic","Porcelain","Rubber","Stone","Styrofoam","Wax","Wood","Wool"])

# %%
result_trans=result.T

# %%
#resultadiv= result.div(7,axis=0)

# %%
from pandas.tools.plotting import radviz

# %%
radviz(result_trans,"")

# %%
result_trans.to_csv("/home/hasan/files/simdatawdT.csv")

# %%
result_trans
# Out:
#            Adhesive  Brick  Cardboard  Ceramic  Cloth  Concrete  Cotton  \
# Adhesive        7.0    1.2        1.2      1.2    1.8       1.0     1.8
# Brick           1.6    7.0        1.6      3.0    1.0       5.8     1.4
# Cardboard       2.2    1.0        7.0      1.2    2.8       1.0     2.8
# Ceramic         1.4    3.0        2.0      7.0    1.0       3.2     1.0
# Cloth           1.6    1.0        2.4      1.2    7.0       1.0     4.6
# Concrete        2.0    4.4        2.0      1.8    1.0       7.0     1.0
# Cotton          1.0    1.0        2.0      1.0    5.8       1.0     7.0
# Diamond         1.0    2.4        1.0      1.4    1.6       3.0     1.0
# Glass           1.4    2.0        1.4      3.4    1.2       1.8     1.4
# Leather         1.4    1.4        1.6      1.0    3.0       1.6     3.0
# Marble          1.0    2.2        1.6      4.6    1.8       3.4     1.6
# Metal           1.4    2.4        1.0      1.6    1.0       2.8     1.0
# ...
