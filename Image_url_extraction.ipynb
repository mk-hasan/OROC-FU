# %%
import pandas as pd

# %%
data= pd.read_csv("/home/hasan/Downloads/cf_report_1281911_full.csv")

# %%
data.head()
# Out:
#            id  \
# 0  3844223449
# 1  3844227993
# 2  3844229416
# 3  3844134335
# 4  3844162096
#
#    on_a_scale_of_1_to_7_how_much_shape1_is_similar_to_shape2__with_7_being_the_highest_level_of_similarity  \
# 0                                                  7
# 1                                                  7
# 2                                                  7
# 3                                                  1
# 4                                                  1
#
#    image_source                                      image_source1  \
# 0           NaN  http://creacogcomp.com/images_shapes_similarit...
# 1           NaN  http://creacogcomp.com/images_shapes_similarit...
# 2           NaN  http://creacogcomp.com/images_shapes_similarit...
# 3           NaN  http://creacogcomp.com/images_shapes_similarit...
# 4           NaN  http://creacogcomp.com/images_shapes_similarit...
#
#                                        image_source2          shape1  \
# ...

# %%
data1= pd.read_csv("/home/hasan/Downloads/cf_report_1283315_full.csv")

# %%
data1.head()
# Out:
#            id  \
# 0  3847112884
# 1  3847148991
# 2  3847149593
# 3  3847179273
# 4  3847187325
#
#    on_a_scale_of_1_to_7_how_much_material1_is_similar_to_material2__with_7_being_the_highest_level_of_similarity  \
# 0                                                  7
# 1                                                  7
# 2                                                  7
# 3                                                  7
# 4                                                  7
#
#   material1 material2    _unit_id         _created_at         _started_at  \
# 0   Ceramic   Ceramic  1810735641  7/13/2018 14:01:21  7/13/2018 14:00:49
# 1   Ceramic   Ceramic  1810735641  7/13/2018 14:16:13  7/13/2018 14:15:42
# 2   Ceramic   Ceramic  1810735641  7/13/2018 14:16:27  7/13/2018 14:15:58
# 3   Ceramic   Ceramic  1810735641  7/13/2018 14:28:18  7/13/2018 14:26:19
# 4   Ceramic   Ceramic  1810735641  7/13/2018 14:31:40  7/13/2018 14:30:27
#
# ...
