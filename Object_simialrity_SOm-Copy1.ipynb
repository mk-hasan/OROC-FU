# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
data_som = pd.read_csv('/home/hasan/Documents/BitRepos/orocv2/som_ms_score.csv')

# %%
data_hum = pd.read_csv('/home/hasan/Documents/BitRepos/orocv2/object_similarityflwid.csv')

# %%
data_dist = pd.read_csv('/home/hasan/Documents/BitRepos/orocv2/distance_data_ext.csv', delimiter=',', encoding="utf-8-sig")

# %%
data_hum.head()
# Out:
#    Unnamed: 0        workerid object1 object2  similarity
# 0           0   ATT3WMHDZNE0F     Cup    Bowl           4
# 1           1  A1V5ETMSSAICW1     Cup    Bowl           6
# 2           2   AKLKDS34ZAGML     Cup    Bowl           5
# 3           3  A3UEM5PCYERMXX     Cup    Bowl           4
# 4           4  A1C4LNTWGUOD4P     Cup    Bowl           5

# %%
data_hum=data_hum.groupby(["object1","object2"],sort=False)["similarity"].mean()

# %%
data_hum.to_csv("/home/hasan/Documents/BitRepos/orocv2/human_simrating.csv")
# Out:
# /home/hasan/anaconda3/envs/BD/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
#   """Entry point for launching an IPython kernel.

# %%
data_hum= pd.read_csv("/home/hasan/Documents/BitRepos/orocv2/human_simrating.csv")

# %%
data_hum.head()
# Out:
#      object1    object2  similarity
# 0        Cup       Bowl         4.8
# 1       Book  Newspaper         4.6
# 2  Newspaper       Book         5.2
# 3       Vase  Container         4.8
# 4  Wallpaper  Newspaper         3.4

# %%
data_dist.head()
# Out:
#   item1_title item2_title  material_dist  shape_dist
# 0         Cup        Bowl         0.3361      0.0517
# 1        Book   Newspaper         0.0000      0.0000
# 2   Newspaper        Book         0.0000      0.0000
# 3        Vase   Container         0.1084      0.0517
# 4   Wallpaper   Newspaper         0.0000      0.0000

# %%
data_dist["avg"]  = data_dist.mean(axis=1)

# %%
data_dist.head()
# Out:
#   item1_title item2_title  material_dist  shape_dist      avg
# 0         Cup        Bowl         0.3361      0.0517  0.19390
# 1        Book   Newspaper         0.0000      0.0000  0.00000
# 2   Newspaper        Book         0.0000      0.0000  0.00000
# 3        Vase   Container         0.1084      0.0517  0.08005
# 4   Wallpaper   Newspaper         0.0000      0.0000  0.00000

# %%
data_som['avg'] = data_som.mean(axis=1)

# %%
data_som['hum_similairty'] = data_hum["similarity"]

# %%
data_som= data_som.rename(columns={'avg': 'som_similairty'})

# %%
data_som["object"]= data_som["item1_title"].map(str)+"-"+data_som["item2_title"]

# %%
data_som["material_dist"] = data_dist["material_dist"]

# %%
data_som["shape_dist"] = data_dist["shape_dist"]

# %%
data_som["dist_avg"] = data_dist["avg"]

# %%
data_som
# Out:
#        item1_title      item2_title   material   shape  som_similairty  \
# 0              Cup             Bowl       7.00    7.00           7.000
# 1             Book        Newspaper       7.00    7.00           7.000
# 2        Newspaper             Book       7.00    7.00           7.000
# 3             Vase        Container       5.69    7.00           6.345
# 4        Wallpaper        Newspaper       7.00    3.60           5.300
# 5            Shelf            Table       7.00    4.26           5.630
# 6        Surfboard             Soap       7.00    4.37           5.685
# 7       PaperTowel   Sheet of Paper       7.00    4.17           5.585
# 8             Soap        Surfboard       7.00    4.06           5.530
# 9       Toothbrush       Coat brush       7.00    7.00           7.000
# 10      Coat brush       Shoe brush       7.00    7.00           7.000
# 11      Shoe brush   Painting brush       7.00    7.00           7.000
# 12           Broom     Toilet brush       7.00    7.00           7.000
# 13    Toilet brush       Coat brush       7.00    7.00           7.000
# 14  Painting brush       Toothbrush       7.00    7.00           7.000
# 15           Table             Desk       7.00    7.00           7.000
# 16            Desk            Table       7.00    5.91           6.455
# 17        Umbrella              Pan       7.00    7.00           7.000
# 18           Spoon              Cup       7.00    4.33           5.665
# 19            Bowl        Container       7.00    7.00           7.000
# 20          Pillow      Pillow case       7.00    7.00           7.000
# 21     Pillow case          Curtain       7.00    4.34           5.670
# 22           Towel    Kitchen Towel       7.00    7.00           7.000
# 23   Kitchen Towel   Bathroom Towel       7.00    7.00           7.000
# 24  Bathroom Towel          Doormat       7.00    7.00           7.000
# 25          Scales              Lid       7.00    7.00           7.000
# 26       Flowerpot              Cup       7.00    7.00           7.000
# 27             Pot              Jar       7.00    7.00           7.000
# 28          Saucer          Ashtray       5.69    3.60           4.645
# 29           Plate             Vase       4.29    3.60           3.945
# 30         Ashtray            Plate       4.29    7.00           5.645
# 31             Pan              Lid       7.00    7.00           7.000
# 32             Lid         Umbrella       7.00    7.00           7.000
# 33             Can              Cup       7.00    7.00           7.000
# 34      Can opener             Nail       7.00    7.00           7.000
# 35          Hammer          Weights       7.00    7.00           7.000
# 36            Nail           Hammer       7.00    7.00           7.000
# 37          Bottle           Bucket       7.00    7.00           7.000
# 38  Sheet of Paper       PaperTowel       7.00    7.00           7.000
# 39         Blanket            Towel       7.00    4.23           5.615
# 40      Sofa Cover      Pillow case       7.00    4.23           5.615
# 41           Sheet              Rug       7.00    4.23           5.615
# 42             Rug    Kitchen Towel       7.00    4.23           5.615
# 43         Doormat          Curtain       7.00    7.00           7.000
# 44         Curtain      Pillow case       7.00    4.23           5.615
# 45     Clothesline            Broom       7.00    4.23           5.615
# 46   Candle Holder        Flowerpot       7.00    7.00           7.000
# 47        Matchbox             Book       5.51    4.34           4.925
# 48             Jar              Pot       7.00    7.00           7.000
# 49       Container              Cup       7.00    7.00           7.000
#
#     hum_similairty                         object  material_dist  shape_dist  \
# 0              4.8                       Cup-Bowl         0.3361      0.0517
# 1              4.6                 Book-Newspaper         0.0000      0.0000
# 2              5.2                 Newspaper-Book         0.0000      0.0000
# 3              4.8                Vase- Container         0.1084      0.0517
# 4              3.4           Wallpaper- Newspaper         0.0000      0.0000
# 5              4.0                    Shelf-Table         0.0000      0.4080
# 6              1.8                Surfboard- Soap         0.0000      0.3494
# 7              5.4      PaperTowel-Sheet of Paper         0.0000      0.2248
# 8              1.6                Soap- Surfboard         0.0000      0.3539
# 9              3.8         Toothbrush- Coat brush         0.0000      0.0000
# 10             5.4         Coat brush- Shoe brush         0.0000      0.0000
# 11             4.2     Shoe brush- Painting brush         0.0000      0.0000
# 12             3.6            Broom- Toilet brush         0.0000      0.0000
# 13             3.8        Toilet brush-Coat brush         0.0000      0.0000
# 14             4.2      Painting brush-Toothbrush         0.0000      0.0000
# 15             6.2                     Table-Desk         0.0000      0.0213
# 16             6.0                    Desk- Table         0.0000      0.0270
# 17             2.2                  Umbrella- Pan         0.1739      0.0484
# 18             2.0                      Spoon-Cup         0.0095      0.0095
# 19             5.2                Bowl- Container         0.0000      0.0517
# 20             3.6            Pillow- Pillow case         0.0000      0.0005
# 21             2.8           Pillow case- Curtain         0.0000      0.3158
# 22             5.0           Towel- Kitchen Towel         0.0000      0.0000
# 23             5.4  Kitchen Towel- Bathroom Towel         0.0000      0.0000
# 24             3.8         Bathroom Towel-Doormat         0.0000      0.0000
# 25             2.4                     Scales-Lid         0.0000      0.0000
# 26             4.6                  Flowerpot-Cup         0.0000      0.0517
# 27             5.4                       Pot- Jar         0.0000      0.0517
# 28             4.8                 Saucer-Ashtray         0.0000      0.0000
# 29             2.2                    Plate- Vase         0.0667      0.7876
# 30             3.6                Ashtray-  Plate         0.0000      0.1084
# 31             2.8                        Pan-Lid         0.0000      0.0484
# 32             1.4                   Lid-Umbrella         0.0000      0.0484
# 33             5.0                        Can-Cup         0.0000      0.0000
# 34             2.4               Can opener- Nail         0.0000      0.7608
# 35             3.2                Hammer- Weights         0.0000      0.0000
# 36             2.2                    Nail-Hammer         0.0000      0.7608
# 37             3.6                  Bottle-Bucket         0.0000      0.0000
# 38             4.8      Sheet of Paper-PaperTowel         0.0000      0.0000
# 39             5.2                  Blanket-Towel         0.0000      0.1739
# 40             3.2         Sofa Cover-Pillow case         0.0000      0.0000
# 41             3.0                     Sheet- Rug         0.0000      0.1739
# 42             4.0             Rug- Kitchen Towel         0.0000      0.7796
# 43             2.4               Doormat- Curtain         0.0000      0.0000
# 44             3.4           Curtain- Pillow case         0.0000      0.3099
# 45             2.6             Clothesline- Broom         0.0000      0.6189
# 46             3.2        Candle Holder-Flowerpot         0.0000      0.0517
# 47             1.8                  Matchbox-Book         0.2248      0.3158
# 48             3.8                       Jar- Pot         0.0000      0.0517
# 49             4.2                  Container-Cup         0.0000      0.0517
#
#     dist_avg
# 0    0.19390
# 1    0.00000
# 2    0.00000
# 3    0.08005
# 4    0.00000
# 5    0.20400
# 6    0.17470
# 7    0.11240
# 8    0.17695
# 9    0.00000
# 10   0.00000
# 11   0.00000
# 12   0.00000
# 13   0.00000
# 14   0.00000
# 15   0.01065
# 16   0.01350
# 17   0.11115
# 18   0.00950
# 19   0.02585
# 20   0.00025
# 21   0.15790
# 22   0.00000
# 23   0.00000
# 24   0.00000
# 25   0.00000
# 26   0.02585
# 27   0.02585
# 28   0.00000
# 29   0.42715
# 30   0.05420
# 31   0.02420
# 32   0.02420
# 33   0.00000
# 34   0.38040
# 35   0.00000
# 36   0.38040
# 37   0.00000
# 38   0.00000
# 39   0.08695
# 40   0.00000
# 41   0.08695
# 42   0.38980
# 43   0.00000
# 44   0.15495
# 45   0.30945
# 46   0.02585
# 47   0.27030
# 48   0.02585
# 49   0.02585

# %%
ax=data_som.plot(figsize=(15,5),x="object",y=['som_similairty','hum_similairty'],kind='bar')
ax.set_ylabel("similarity")
# Out:
# Text(0, 0.5, 'similarity')

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

data_som[[" material"," shape","som_similairty","hum_similairty","material_dist","shape_dist","dist_avg"]] = scaler.fit_transform(data_som[[" material"," shape","som_similairty","hum_similairty","material_dist","shape_dist","dist_avg"]])

# %%
data_som
# Out:
#        item1_title      item2_title   material     shape  som_similairty  \
# 0              Cup             Bowl   1.000000  1.000000        1.000000
# 1             Book        Newspaper   1.000000  1.000000        1.000000
# 2        Newspaper             Book   1.000000  1.000000        1.000000
# 3             Vase        Container   0.516605  1.000000        0.785597
# 4        Wallpaper        Newspaper   1.000000  0.000000        0.443535
# 5            Shelf            Table   1.000000  0.194118        0.551555
# 6        Surfboard             Soap   1.000000  0.226471        0.569558
# 7       PaperTowel   Sheet of Paper   1.000000  0.167647        0.536825
# 8             Soap        Surfboard   1.000000  0.135294        0.518822
# 9       Toothbrush       Coat brush   1.000000  1.000000        1.000000
# 10      Coat brush       Shoe brush   1.000000  1.000000        1.000000
# 11      Shoe brush   Painting brush   1.000000  1.000000        1.000000
# 12           Broom     Toilet brush   1.000000  1.000000        1.000000
# 13    Toilet brush       Coat brush   1.000000  1.000000        1.000000
# 14  Painting brush       Toothbrush   1.000000  1.000000        1.000000
# 15           Table             Desk   1.000000  1.000000        1.000000
# 16            Desk            Table   1.000000  0.679412        0.821604
# 17        Umbrella              Pan   1.000000  1.000000        1.000000
# 18           Spoon              Cup   1.000000  0.214706        0.563011
# 19            Bowl        Container   1.000000  1.000000        1.000000
# 20          Pillow      Pillow case   1.000000  1.000000        1.000000
# 21     Pillow case          Curtain   1.000000  0.217647        0.564648
# 22           Towel    Kitchen Towel   1.000000  1.000000        1.000000
# 23   Kitchen Towel   Bathroom Towel   1.000000  1.000000        1.000000
# 24  Bathroom Towel          Doormat   1.000000  1.000000        1.000000
# 25          Scales              Lid   1.000000  1.000000        1.000000
# 26       Flowerpot              Cup   1.000000  1.000000        1.000000
# 27             Pot              Jar   1.000000  1.000000        1.000000
# 28          Saucer          Ashtray   0.516605  0.000000        0.229133
# 29           Plate             Vase   0.000000  0.000000        0.000000
# 30         Ashtray            Plate   0.000000  1.000000        0.556465
# 31             Pan              Lid   1.000000  1.000000        1.000000
# 32             Lid         Umbrella   1.000000  1.000000        1.000000
# 33             Can              Cup   1.000000  1.000000        1.000000
# 34      Can opener             Nail   1.000000  1.000000        1.000000
# 35          Hammer          Weights   1.000000  1.000000        1.000000
# 36            Nail           Hammer   1.000000  1.000000        1.000000
# 37          Bottle           Bucket   1.000000  1.000000        1.000000
# 38  Sheet of Paper       PaperTowel   1.000000  1.000000        1.000000
# 39         Blanket            Towel   1.000000  0.185294        0.546645
# 40      Sofa Cover      Pillow case   1.000000  0.185294        0.546645
# 41           Sheet              Rug   1.000000  0.185294        0.546645
# 42             Rug    Kitchen Towel   1.000000  0.185294        0.546645
# 43         Doormat          Curtain   1.000000  1.000000        1.000000
# 44         Curtain      Pillow case   1.000000  0.185294        0.546645
# 45     Clothesline            Broom   1.000000  0.185294        0.546645
# 46   Candle Holder        Flowerpot   1.000000  1.000000        1.000000
# 47        Matchbox             Book   0.450185  0.217647        0.320786
# 48             Jar              Pot   1.000000  1.000000        1.000000
# 49       Container              Cup   1.000000  1.000000        1.000000
#
#     hum_similairty                         object  material_dist  shape_dist  \
# 0         0.708333                       Cup-Bowl       1.000000    0.065642
# 1         0.666667                 Book-Newspaper       0.000000    0.000000
# 2         0.791667                 Newspaper-Book       0.000000    0.000000
# 3         0.708333                Vase- Container       0.322523    0.065642
# 4         0.416667           Wallpaper- Newspaper       0.000000    0.000000
# 5         0.541667                    Shelf-Table       0.000000    0.518029
# 6         0.083333                Surfboard- Soap       0.000000    0.443626
# 7         0.833333      PaperTowel-Sheet of Paper       0.000000    0.285424
# 8         0.041667                Soap- Surfboard       0.000000    0.449340
# 9         0.500000         Toothbrush- Coat brush       0.000000    0.000000
# 10        0.833333         Coat brush- Shoe brush       0.000000    0.000000
# 11        0.583333     Shoe brush- Painting brush       0.000000    0.000000
# 12        0.458333            Broom- Toilet brush       0.000000    0.000000
# 13        0.500000        Toilet brush-Coat brush       0.000000    0.000000
# 14        0.583333      Painting brush-Toothbrush       0.000000    0.000000
# 15        1.000000                     Table-Desk       0.000000    0.027044
# 16        0.958333                    Desk- Table       0.000000    0.034281
# 17        0.166667                  Umbrella- Pan       0.517406    0.061453
# 18        0.125000                      Spoon-Cup       0.028265    0.012062
# 19        0.791667                Bowl- Container       0.000000    0.065642
# 20        0.458333            Pillow- Pillow case       0.000000    0.000635
# 21        0.291667           Pillow case- Curtain       0.000000    0.400965
# 22        0.750000           Towel- Kitchen Towel       0.000000    0.000000
# 23        0.833333  Kitchen Towel- Bathroom Towel       0.000000    0.000000
# 24        0.500000         Bathroom Towel-Doormat       0.000000    0.000000
# 25        0.208333                     Scales-Lid       0.000000    0.000000
# 26        0.666667                  Flowerpot-Cup       0.000000    0.065642
# 27        0.833333                       Pot- Jar       0.000000    0.065642
# 28        0.708333                 Saucer-Ashtray       0.000000    0.000000
# 29        0.166667                    Plate- Vase       0.198453    1.000000
# 30        0.458333                Ashtray-  Plate       0.000000    0.137633
# 31        0.291667                        Pan-Lid       0.000000    0.061453
# 32        0.000000                   Lid-Umbrella       0.000000    0.061453
# 33        0.750000                        Can-Cup       0.000000    0.000000
# 34        0.208333               Can opener- Nail       0.000000    0.965973
# 35        0.375000                Hammer- Weights       0.000000    0.000000
# 36        0.166667                    Nail-Hammer       0.000000    0.965973
# 37        0.458333                  Bottle-Bucket       0.000000    0.000000
# 38        0.708333      Sheet of Paper-PaperTowel       0.000000    0.000000
# 39        0.791667                  Blanket-Towel       0.000000    0.220797
# 40        0.375000         Sofa Cover-Pillow case       0.000000    0.000000
# 41        0.333333                     Sheet- Rug       0.000000    0.220797
# 42        0.541667             Rug- Kitchen Towel       0.000000    0.989843
# 43        0.208333               Doormat- Curtain       0.000000    0.000000
# 44        0.416667           Curtain- Pillow case       0.000000    0.393474
# 45        0.250000             Clothesline- Broom       0.000000    0.785805
# 46        0.375000        Candle Holder-Flowerpot       0.000000    0.065642
# 47        0.083333                  Matchbox-Book       0.668849    0.400965
# 48        0.500000                       Jar- Pot       0.000000    0.065642
# 49        0.583333                  Container-Cup       0.000000    0.065642
#
#     dist_avg
# 0   0.453939
# 1   0.000000
# 2   0.000000
# 3   0.187405
# 4   0.000000
# 5   0.477584
# 6   0.408990
# 7   0.263139
# 8   0.414257
# 9   0.000000
# 10  0.000000
# 11  0.000000
# 12  0.000000
# 13  0.000000
# 14  0.000000
# 15  0.024933
# 16  0.031605
# 17  0.260213
# 18  0.022240
# 19  0.060517
# 20  0.000585
# 21  0.369659
# 22  0.000000
# 23  0.000000
# 24  0.000000
# 25  0.000000
# 26  0.060517
# 27  0.060517
# 28  0.000000
# 29  1.000000
# 30  0.126888
# 31  0.056655
# 32  0.056655
# 33  0.000000
# 34  0.890554
# 35  0.000000
# 36  0.890554
# 37  0.000000
# 38  0.000000
# 39  0.203558
# 40  0.000000
# 41  0.203558
# 42  0.912560
# 43  0.000000
# 44  0.362753
# 45  0.724453
# 46  0.060517
# 47  0.632799
# 48  0.060517
# 49  0.060517

# %%
data_som=data_som.rename(columns={" material":"hum_m"," shape":"hum_s","som_similairty":"mean(hum_s,hum_m)","hum_similairty":"hum_simRating","material_dist":"som_material","shape_dist":"som_shape","dist_avg":"mean(som_mat,som_shape)"})

# %%
data_som
# Out:
#        item1_title      item2_title     hum_m     hum_s  mean(hum_s,hum_m)  \
# 0              Cup             Bowl  1.000000  1.000000           1.000000
# 1             Book        Newspaper  1.000000  1.000000           1.000000
# 2        Newspaper             Book  1.000000  1.000000           1.000000
# 3             Vase        Container  0.516605  1.000000           0.785597
# 4        Wallpaper        Newspaper  1.000000  0.000000           0.443535
# 5            Shelf            Table  1.000000  0.194118           0.551555
# 6        Surfboard             Soap  1.000000  0.226471           0.569558
# 7       PaperTowel   Sheet of Paper  1.000000  0.167647           0.536825
# 8             Soap        Surfboard  1.000000  0.135294           0.518822
# 9       Toothbrush       Coat brush  1.000000  1.000000           1.000000
# 10      Coat brush       Shoe brush  1.000000  1.000000           1.000000
# 11      Shoe brush   Painting brush  1.000000  1.000000           1.000000
# 12           Broom     Toilet brush  1.000000  1.000000           1.000000
# 13    Toilet brush       Coat brush  1.000000  1.000000           1.000000
# 14  Painting brush       Toothbrush  1.000000  1.000000           1.000000
# 15           Table             Desk  1.000000  1.000000           1.000000
# 16            Desk            Table  1.000000  0.679412           0.821604
# 17        Umbrella              Pan  1.000000  1.000000           1.000000
# 18           Spoon              Cup  1.000000  0.214706           0.563011
# 19            Bowl        Container  1.000000  1.000000           1.000000
# 20          Pillow      Pillow case  1.000000  1.000000           1.000000
# 21     Pillow case          Curtain  1.000000  0.217647           0.564648
# 22           Towel    Kitchen Towel  1.000000  1.000000           1.000000
# 23   Kitchen Towel   Bathroom Towel  1.000000  1.000000           1.000000
# 24  Bathroom Towel          Doormat  1.000000  1.000000           1.000000
# 25          Scales              Lid  1.000000  1.000000           1.000000
# 26       Flowerpot              Cup  1.000000  1.000000           1.000000
# 27             Pot              Jar  1.000000  1.000000           1.000000
# 28          Saucer          Ashtray  0.516605  0.000000           0.229133
# 29           Plate             Vase  0.000000  0.000000           0.000000
# 30         Ashtray            Plate  0.000000  1.000000           0.556465
# 31             Pan              Lid  1.000000  1.000000           1.000000
# 32             Lid         Umbrella  1.000000  1.000000           1.000000
# 33             Can              Cup  1.000000  1.000000           1.000000
# 34      Can opener             Nail  1.000000  1.000000           1.000000
# 35          Hammer          Weights  1.000000  1.000000           1.000000
# 36            Nail           Hammer  1.000000  1.000000           1.000000
# 37          Bottle           Bucket  1.000000  1.000000           1.000000
# 38  Sheet of Paper       PaperTowel  1.000000  1.000000           1.000000
# 39         Blanket            Towel  1.000000  0.185294           0.546645
# 40      Sofa Cover      Pillow case  1.000000  0.185294           0.546645
# 41           Sheet              Rug  1.000000  0.185294           0.546645
# 42             Rug    Kitchen Towel  1.000000  0.185294           0.546645
# 43         Doormat          Curtain  1.000000  1.000000           1.000000
# 44         Curtain      Pillow case  1.000000  0.185294           0.546645
# 45     Clothesline            Broom  1.000000  0.185294           0.546645
# 46   Candle Holder        Flowerpot  1.000000  1.000000           1.000000
# 47        Matchbox             Book  0.450185  0.217647           0.320786
# 48             Jar              Pot  1.000000  1.000000           1.000000
# 49       Container              Cup  1.000000  1.000000           1.000000
#
#     hum_simRating                         object  som_material  som_shape  \
# 0        0.708333                       Cup-Bowl      1.000000   0.065642
# 1        0.666667                 Book-Newspaper      0.000000   0.000000
# 2        0.791667                 Newspaper-Book      0.000000   0.000000
# 3        0.708333                Vase- Container      0.322523   0.065642
# 4        0.416667           Wallpaper- Newspaper      0.000000   0.000000
# 5        0.541667                    Shelf-Table      0.000000   0.518029
# 6        0.083333                Surfboard- Soap      0.000000   0.443626
# 7        0.833333      PaperTowel-Sheet of Paper      0.000000   0.285424
# 8        0.041667                Soap- Surfboard      0.000000   0.449340
# 9        0.500000         Toothbrush- Coat brush      0.000000   0.000000
# 10       0.833333         Coat brush- Shoe brush      0.000000   0.000000
# 11       0.583333     Shoe brush- Painting brush      0.000000   0.000000
# 12       0.458333            Broom- Toilet brush      0.000000   0.000000
# 13       0.500000        Toilet brush-Coat brush      0.000000   0.000000
# 14       0.583333      Painting brush-Toothbrush      0.000000   0.000000
# 15       1.000000                     Table-Desk      0.000000   0.027044
# 16       0.958333                    Desk- Table      0.000000   0.034281
# 17       0.166667                  Umbrella- Pan      0.517406   0.061453
# 18       0.125000                      Spoon-Cup      0.028265   0.012062
# 19       0.791667                Bowl- Container      0.000000   0.065642
# 20       0.458333            Pillow- Pillow case      0.000000   0.000635
# 21       0.291667           Pillow case- Curtain      0.000000   0.400965
# 22       0.750000           Towel- Kitchen Towel      0.000000   0.000000
# 23       0.833333  Kitchen Towel- Bathroom Towel      0.000000   0.000000
# 24       0.500000         Bathroom Towel-Doormat      0.000000   0.000000
# 25       0.208333                     Scales-Lid      0.000000   0.000000
# 26       0.666667                  Flowerpot-Cup      0.000000   0.065642
# 27       0.833333                       Pot- Jar      0.000000   0.065642
# 28       0.708333                 Saucer-Ashtray      0.000000   0.000000
# 29       0.166667                    Plate- Vase      0.198453   1.000000
# 30       0.458333                Ashtray-  Plate      0.000000   0.137633
# 31       0.291667                        Pan-Lid      0.000000   0.061453
# 32       0.000000                   Lid-Umbrella      0.000000   0.061453
# 33       0.750000                        Can-Cup      0.000000   0.000000
# 34       0.208333               Can opener- Nail      0.000000   0.965973
# 35       0.375000                Hammer- Weights      0.000000   0.000000
# 36       0.166667                    Nail-Hammer      0.000000   0.965973
# 37       0.458333                  Bottle-Bucket      0.000000   0.000000
# 38       0.708333      Sheet of Paper-PaperTowel      0.000000   0.000000
# 39       0.791667                  Blanket-Towel      0.000000   0.220797
# 40       0.375000         Sofa Cover-Pillow case      0.000000   0.000000
# 41       0.333333                     Sheet- Rug      0.000000   0.220797
# 42       0.541667             Rug- Kitchen Towel      0.000000   0.989843
# 43       0.208333               Doormat- Curtain      0.000000   0.000000
# 44       0.416667           Curtain- Pillow case      0.000000   0.393474
# 45       0.250000             Clothesline- Broom      0.000000   0.785805
# 46       0.375000        Candle Holder-Flowerpot      0.000000   0.065642
# 47       0.083333                  Matchbox-Book      0.668849   0.400965
# 48       0.500000                       Jar- Pot      0.000000   0.065642
# 49       0.583333                  Container-Cup      0.000000   0.065642
#
#     mean(som_mat,som_shape)
# 0                  0.453939
# 1                  0.000000
# 2                  0.000000
# 3                  0.187405
# 4                  0.000000
# 5                  0.477584
# 6                  0.408990
# 7                  0.263139
# 8                  0.414257
# 9                  0.000000
# 10                 0.000000
# 11                 0.000000
# 12                 0.000000
# 13                 0.000000
# 14                 0.000000
# 15                 0.024933
# 16                 0.031605
# 17                 0.260213
# 18                 0.022240
# 19                 0.060517
# 20                 0.000585
# 21                 0.369659
# 22                 0.000000
# 23                 0.000000
# 24                 0.000000
# 25                 0.000000
# 26                 0.060517
# 27                 0.060517
# 28                 0.000000
# 29                 1.000000
# 30                 0.126888
# 31                 0.056655
# 32                 0.056655
# 33                 0.000000
# 34                 0.890554
# 35                 0.000000
# 36                 0.890554
# 37                 0.000000
# 38                 0.000000
# 39                 0.203558
# 40                 0.000000
# 41                 0.203558
# 42                 0.912560
# 43                 0.000000
# 44                 0.362753
# 45                 0.724453
# 46                 0.060517
# 47                 0.632799
# 48                 0.060517
# 49                 0.060517

# %%
data_som.corr(method='pearson')
# Out:
#                             hum_m     hum_s  mean(hum_s,hum_m)  hum_simRating  \
# hum_m                    1.000000  0.212222           0.563102       0.129103
# hum_s                    0.212222  1.000000           0.927066       0.270562
# mean(hum_s,hum_m)        0.563102  0.927066           1.000000       0.278330
# hum_simRating            0.129103  0.270562           0.278330       1.000000
# som_material            -0.255088  0.003564          -0.094847      -0.096425
# som_shape               -0.232071 -0.466384          -0.483429      -0.403989
# mean(som_mat,som_shape) -0.288116 -0.445287          -0.487089      -0.411494
#
#                          som_material  som_shape  mean(som_mat,som_shape)
# hum_m                       -0.255088  -0.232071                -0.288116
# hum_s                        0.003564  -0.466384                -0.445287
# mean(hum_s,hum_m)           -0.094847  -0.483429                -0.487089
# hum_simRating               -0.096425  -0.403989                -0.411494
# som_material                 1.000000   0.035359                 0.292891
# som_shape                    0.035359   1.000000                 0.965904
# mean(som_mat,som_shape)      0.292891   0.965904                 1.000000

# %%
import seaborn as sns
sns.heatmap(data_som.corr(method='pearson'),size=30)
# Out:
# ----------------------------------------------------------------------
# AttributeError                       Traceback (most recent call last)
# <ipython-input-113-41046fe3027a> in <module>
#       1 import seaborn as sns
# ----> 2 sns.heatmap(data_som.corr(method='pearson'),size=30)
#
# ~/anaconda3/envs/BD/lib/python3.7/site-packages/seaborn/matrix.py in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     526     if square:
#     527         ax.set_aspect("equal")
# --> 528     plotter.plot(ax, cbar_ax, kwargs)
#     529     return ax
#     530
#
# ~/anaconda3/envs/BD/lib/python3.7/site-packages/seaborn/matrix.py in plot(self, ax, cax, kws)
#     282         # Draw the heatmap
#     283         mesh = ax.pcolormesh(self.plot_data, vmin=self.vmin, vmax=self.vmax,
# --> 284                              cmap=self.cmap, **kws)
#     285
#     286         # Set the axis limits
#
# ~/anaconda3/envs/BD/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1587     def inner(ax, *args, data=None, **kwargs):
#    1588         if data is None:
# -> 1589             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1590
#    1591         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/anaconda3/envs/BD/lib/python3.7/site-packages/matplotlib/axes/_axes.py in pcolormesh(self, alpha, norm, cmap, vmin, vmax, shading, antialiased, *args, **kwargs)
#    6158         collection = mcoll.QuadMesh(Nx - 1, Ny - 1, coords,
#    6159                                     antialiased=antialiased, shading=shading,
# -> 6160                                     **kwargs)
#    6161         collection.set_alpha(alpha)
#    6162         collection.set_array(C)
#
# ~/anaconda3/envs/BD/lib/python3.7/site-packages/matplotlib/collections.py in __init__(self, meshWidth, meshHeight, coordinates, antialiased, shading, **kwargs)
#    1910     def __init__(self, meshWidth, meshHeight, coordinates,
#    1911                  antialiased=True, shading='flat', **kwargs):
# -> 1912         Collection.__init__(self, **kwargs)
#    1913         self._meshWidth = meshWidth
#    1914         self._meshHeight = meshHeight
#
# ~/anaconda3/envs/BD/lib/python3.7/site-packages/matplotlib/collections.py in __init__(self, edgecolors, facecolors, linewidths, linestyles, capstyle, joinstyle, antialiaseds, offsets, transOffset, norm, cmap, pickradius, hatch, urls, offset_position, zorder, **kwargs)
#     160
#     161         self._path_effects = None
# --> 162         self.update(kwargs)
#     163         self._paths = None
#     164
#
# ~/anaconda3/envs/BD/lib/python3.7/site-packages/matplotlib/artist.py in update(self, props)
#     955
#     956         with cbook._setattr_cm(self, eventson=False):
# --> 957             ret = [_update_property(self, k, v) for k, v in props.items()]
#     958
#     959         if len(ret):
#
# ~/anaconda3/envs/BD/lib/python3.7/site-packages/matplotlib/artist.py in <listcomp>(.0)
#     955
#     956         with cbook._setattr_cm(self, eventson=False):
# --> 957             ret = [_update_property(self, k, v) for k, v in props.items()]
#     958
#     959         if len(ret):
#
# ~/anaconda3/envs/BD/lib/python3.7/site-packages/matplotlib/artist.py in _update_property(self, k, v)
#     951                 if not callable(func):
#     952                     raise AttributeError('{!r} object has no property {!r}'
# --> 953                                          .format(type(self).__name__, k))
#     954                 return func(v)
#     955
#
# AttributeError: 'QuadMesh' object has no property 'size'

# %%
import matplotlib.pyplot as plt
import seaborn as sns

for var in data_som[["hum_m","hum_s","mean(hum_s,hum_m)","hum_simRating","som_material","som_shape","mean(som_mat,som_shape)"]]:
    sns.regplot(data_som[var],data_som["hum_simRating"])
    plt.show()
