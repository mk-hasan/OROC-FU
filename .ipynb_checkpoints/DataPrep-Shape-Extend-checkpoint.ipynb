# %%
import numpy as np
import pandas as pd

# %%
shape_dataset = pd.read_csv("/home/hasan/Downloads/Batch_3742618_batch_results.csv")

# %%
shape_dataset.head()
# Out:
#                             HITId                       HITTypeId  \
# 0  3HKIF5DF6ZAXB36MKU0GQA7YX2J9GG  3GC398RH53D7U3QVL2N9V8SXVM3KP0
# 1  3HKIF5DF6ZAXB36MKU0GQA7YX2J9GG  3GC398RH53D7U3QVL2N9V8SXVM3KP0
# 2  3HKIF5DF6ZAXB36MKU0GQA7YX2J9GG  3GC398RH53D7U3QVL2N9V8SXVM3KP0
# 3  3HKIF5DF6ZAXB36MKU0GQA7YX2J9GG  3GC398RH53D7U3QVL2N9V8SXVM3KP0
# 4  3HKIF5DF6ZAXB36MKU0GQA7YX2J9GG  3GC398RH53D7U3QVL2N9V8SXVM3KP0
#
#                                 Title  \
# 0  How similar are the two materials?
# 1  How similar are the two materials?
# 2  How similar are the two materials?
# 3  How similar are the two materials?
# 4  How similar are the two materials?
#
#                                          Description  \
# 0  In this task you will compare two sets of mate...
# 1  In this task you will compare two sets of mate...
# 2  In this task you will compare two sets of mate...
# 3  In this task you will compare two sets of mate...
# 4  In this task you will compare two sets of mate...
#
#                      Keywords Reward                  CreationTime  \
# 0  item, equality, comparison  $0.02  Wed Aug 21 08:16:06 PDT 2019
# 1  item, equality, comparison  $0.02  Wed Aug 21 08:16:06 PDT 2019
# 2  item, equality, comparison  $0.02  Wed Aug 21 08:16:06 PDT 2019
# 3  item, equality, comparison  $0.02  Wed Aug 21 08:16:06 PDT 2019
# 4  item, equality, comparison  $0.02  Wed Aug 21 08:16:06 PDT 2019
#
#    MaxAssignments                               RequesterAnnotation  \
# 0              35  BatchId:3742618;OriginalHitTemplateId:928390889;
# 1              35  BatchId:3742618;OriginalHitTemplateId:928390889;
# 2              35  BatchId:3742618;OriginalHitTemplateId:928390889;
# 3              35  BatchId:3742618;OriginalHitTemplateId:928390889;
# 4              35  BatchId:3742618;OriginalHitTemplateId:928390889;
#
#    AssignmentDurationInSeconds  ...  WorkTimeInSeconds LifetimeApprovalRate  \
# 0                          300  ...                  6             0% (0/0)
# 1                          300  ...                  4           100% (2/2)
# 2                          300  ...                  9             0% (0/0)
# 3                          300  ...                162       100% (116/116)
# 4                          300  ...                  6             0% (0/0)
#
#    Last30DaysApprovalRate  Last7DaysApprovalRate Input.item1_title  \
# 0                0% (0/0)               0% (0/0)           Ceramic
# 1                0% (0/0)               0% (0/0)           Ceramic
# 2                0% (0/0)               0% (0/0)           Ceramic
# 3                0% (0/0)               0% (0/0)           Ceramic
# 4                0% (0/0)               0% (0/0)           Ceramic
#
#   Input.item2_title Answer.equal Answer.equal.label Approve Reject
# 0             Paper          NaN           Very Low     NaN    NaN
# 1             Paper          NaN           Very Low     NaN    NaN
# 2             Paper          NaN                Low     NaN    NaN
# 3             Paper          NaN           Very Low     NaN    NaN
# 4             Paper          NaN                Low     NaN    NaN
#
# [5 rows x 33 columns]

# %%
shape_dataset= shape_dataset.drop(['HITId','HITTypeId','Title','Description','Keywords','Reward','CreationTime','MaxAssignments','RequesterFeedback','WorkTimeInSeconds','LifetimeApprovalRate','Last30DaysApprovalRate','Last7DaysApprovalRate','Approve','Reject'],axis=1)

# %%
shape_dataset.head()
# Out:
#                                 RequesterAnnotation  \
# 0  BatchId:3742618;OriginalHitTemplateId:928390889;
# 1  BatchId:3742618;OriginalHitTemplateId:928390889;
# 2  BatchId:3742618;OriginalHitTemplateId:928390889;
# 3  BatchId:3742618;OriginalHitTemplateId:928390889;
# 4  BatchId:3742618;OriginalHitTemplateId:928390889;
#
#    AssignmentDurationInSeconds  AutoApprovalDelayInSeconds  \
# 0                          300                     2592000
# 1                          300                     2592000
# 2                          300                     2592000
# 3                          300                     2592000
# 4                          300                     2592000
#
#                      Expiration  NumberOfSimilarHITs  LifetimeInSeconds  \
# 0  Tue Sep 10 08:16:06 PDT 2019                  NaN                NaN
# 1  Tue Sep 10 08:16:06 PDT 2019                  NaN                NaN
# 2  Tue Sep 10 08:16:06 PDT 2019                  NaN                NaN
# 3  Tue Sep 10 08:16:06 PDT 2019                  NaN                NaN
# 4  Tue Sep 10 08:16:06 PDT 2019                  NaN                NaN
#
#                      AssignmentId        WorkerId AssignmentStatus  \
# 0  3018Q3ZVOK35RWMZIDDUATSCTO5ARG  A34AQDMF5GVHVY        Submitted
# 1  32Q90QCQ1UYMU5QG8Y6J50WPJB2KEL  A2C73Y1COWCA51        Submitted
# 2  32VNZTT0A9HQP76I9C33XQ6C1EJ4R9  A1Q7OOR64JJRCO        Submitted
# 3  358010RM5G69GGB927AIVYSDFFPXVY  A2MCG5W6LHSRG9        Submitted
# 4  35K3O9HUADQBEJY27NFMPN4KBF1FEU   AHCNB3U5FYB4N        Submitted
#
#                      AcceptTime                    SubmitTime  \
# 0  Wed Aug 21 08:30:22 PDT 2019  Wed Aug 21 08:30:28 PDT 2019
# 1  Wed Aug 21 08:18:48 PDT 2019  Wed Aug 21 08:18:52 PDT 2019
# 2  Wed Aug 21 08:44:51 PDT 2019  Wed Aug 21 08:45:00 PDT 2019
# 3  Wed Aug 21 08:28:25 PDT 2019  Wed Aug 21 08:31:07 PDT 2019
# 4  Wed Aug 21 08:43:38 PDT 2019  Wed Aug 21 08:43:44 PDT 2019
#
#                AutoApprovalTime  ApprovalTime  RejectionTime  \
# 0  Fri Sep 20 08:30:28 PDT 2019           NaN            NaN
# 1  Fri Sep 20 08:18:52 PDT 2019           NaN            NaN
# 2  Fri Sep 20 08:45:00 PDT 2019           NaN            NaN
# 3  Fri Sep 20 08:31:07 PDT 2019           NaN            NaN
# 4  Fri Sep 20 08:43:44 PDT 2019           NaN            NaN
#
#   Input.item1_title Input.item2_title Answer.equal Answer.equal.label
# 0           Ceramic             Paper          NaN           Very Low
# 1           Ceramic             Paper          NaN           Very Low
# 2           Ceramic             Paper          NaN                Low
# 3           Ceramic             Paper          NaN           Very Low
# 4           Ceramic             Paper          NaN                Low

# %%
shape_dataset = shape_dataset.drop(['RequesterAnnotation','AssignmentDurationInSeconds','AutoApprovalDelayInSeconds','Expiration','NumberOfSimilarHITs','LifetimeInSeconds','AssignmentId','AssignmentStatus','AcceptTime','SubmitTime','AutoApprovalTime','RejectionTime'],axis=1)

# %%
shape_dataset = shape_dataset.drop(['ApprovalTime','Answer.equal'],axis=1)

# %%
shape_dataset.head()
# Out:
#          WorkerId Input.item1_title Input.item2_title Answer.equal.label
# 0  A34AQDMF5GVHVY           Ceramic             Paper           Very Low
# 1  A2C73Y1COWCA51           Ceramic             Paper           Very Low
# 2  A1Q7OOR64JJRCO           Ceramic             Paper                Low
# 3  A2MCG5W6LHSRG9           Ceramic             Paper           Very Low
# 4   AHCNB3U5FYB4N           Ceramic             Paper                Low

# %%
shape_dataset.columns = ['workerid','object1','object2','similarity']

# %%
shape_dataset.to_csv("/home/hasan/Documents/BitRepos/orocv2/Material-data-extend.csv")

# %%
data_t = pd.read_csv("/home/hasan/Documents/BitRepos/orocv2/Material-data-extend.csv")

# %%
data_t.loc[data_t['similarity'] == 'Very High', ['similarity']] = 7
data_t.loc[data_t['similarity'] == 'High', ['similarity']] = 6
data_t.loc[data_t['similarity'] == 'Medium High', ['similarity']] = 5
data_t.loc[data_t['similarity'] == 'Medium', ['similarity']] = 4
data_t.loc[data_t['similarity'] == 'Medium Low', ['similarity']] = 3
data_t.loc[data_t['similarity'] == 'Low', ['similarity']] = 2
data_t.loc[data_t['similarity'] == 'Very Low', ['similarity']] = 1

# %%
data_t = data_t.drop('workerid',axis=1)

# %%
data_t.head()
# Out:
#    Unnamed: 0        workerid  object1 object2 similarity
# 0           0  A34AQDMF5GVHVY  Ceramic   Paper          1
# 1           1  A2C73Y1COWCA51  Ceramic   Paper          1
# 2           2  A1Q7OOR64JJRCO  Ceramic   Paper          2
# 3           3  A2MCG5W6LHSRG9  Ceramic   Paper          1
# 4           4   AHCNB3U5FYB4N  Ceramic   Paper          2

# %%
material_data_ex = data_t.groupby(["object1","object2"]).mean()

# %%
material_data_ex.head()
# Out:
#                     Unnamed: 0
# object1  object2
# Adhesive Brick           10342
#          Cardboard       10062
#          Ceramic          9292
#          Cloth            9887
#          Concrete        10307

# %%
material_data_ex.to_csv("/home/hasan/Documents/BitRepos/orocv2/Material-data-extend-mean.csv")

# %%
material_data_ex_mean = pd.read_csv("/home/hasan/Documents/BitRepos/orocv2/Material-data-extend-mean.csv", names=["material1","material2","similarity"])

# %%
material_data_ex_mean=material_data_ex_mean.iloc[1:]

# %%
material_data_ex_mean.head()
# Out:
#   material1  material2 similarity
# 1  Adhesive      Brick      10342
# 2  Adhesive  Cardboard      10062
# 3  Adhesive    Ceramic       9292
# 4  Adhesive      Cloth       9887
# 5  Adhesive   Concrete      10307

# %%
result_trans=result.T

# %%
from pandas.tools.plotting import radviz

# %%
result_trans.head()
# Out:
#                            cuboid  cylinder  handle with bristles  \
# cuboid                   7.000000  2.333333              1.000000
# cylinder                 2.333333  7.000000              1.000000
# handle with bristles     1.000000  1.666667              7.000000
# high convexity           1.000000  4.000000              1.333333
# long narrow rectangular  4.000000  2.666667              1.000000
#
#                          high convexity  long narrow rectangular  \
# cuboid                         2.000000                 4.000000
# cylinder                       4.333333                 3.000000
# handle with bristles           1.000000                 2.333333
# high convexity                 7.000000                 3.666667
# long narrow rectangular        2.666667                 7.000000
#
#                          medium convexity with handle  \
# cuboid                                       1.666667
# cylinder                                     4.333333
# handle with bristles                         1.000000
# high convexity                               3.666667
# long narrow rectangular                      1.000000
#
#                          rectangular thin with legs  \
# cuboid                                     4.333333
# cylinder                                   1.666667
# handle with bristles                       1.333333
# high convexity                             1.000000
# long narrow rectangular                    4.666667
#
#                          rectangular thin with legs and drawers  \
# cuboid                                                 4.666667
# cylinder                                               1.000000
# handle with bristles                                   1.333333
# high convexity                                         1.000000
# long narrow rectangular                                4.000000
#
#                          small thick rectangular  thin rectangular
# cuboid                                  5.666667          3.666667
# cylinder                                1.000000          1.000000
# handle with bristles                    1.666667          1.666667
# high convexity                          1.000000          1.000000
# long narrow rectangular                 3.666667          5.666667

# %%
result_trans.to_csv("/home/hasan/files/shape_data_mean_T")
