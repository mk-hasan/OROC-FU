# %%
import numpy as np
import pandas as pd

# %%
shape_dataset = pd.read_csv("/home/hasan/files/cf_report_1281911_full.csv")

# %%
shape_dataset.head()
# Out:
#            id  \
# 0  3844223449
# 1  3844227993
# 2  3844229416
# 3  3844134335
# 4  3844162096
#
#    on_a_scale_of_1_to_7_how_much_shape1_is_similar_to_shape2__with_7_being_the_highest_level_of_similarity  \
# 0                                                  7
# 1                                                  7
# 2                                                  7
# 3                                                  1
# 4                                                  1
#
#    image_source                                      image_source1  \
# 0           NaN  http://creacogcomp.com/images_shapes_similarit...
# 1           NaN  http://creacogcomp.com/images_shapes_similarit...
# 2           NaN  http://creacogcomp.com/images_shapes_similarit...
# 3           NaN  http://creacogcomp.com/images_shapes_similarit...
# 4           NaN  http://creacogcomp.com/images_shapes_similarit...
#
#                                        image_source2          shape1  \
# 0  http://creacogcomp.com/images_shapes_similarit...  high convexity
# 1  http://creacogcomp.com/images_shapes_similarit...  high convexity
# 2  http://creacogcomp.com/images_shapes_similarit...  high convexity
# 3  http://creacogcomp.com/images_shapes_similarit...  high convexity
# 4  http://creacogcomp.com/images_shapes_similarit...  high convexity
#
#              shape2
# 0    high convexity
# 1    high convexity
# 2    high convexity
# 3  thin rectangular
# 4  thin rectangular

# %%
shape_dataset= shape_dataset.drop(["id","image_source","image_source1","image_source2"],1)

# %%
shape_dataset.head()
# Out:
#    on_a_scale_of_1_to_7_how_much_shape1_is_similar_to_shape2__with_7_being_the_highest_level_of_similarity  \
# 0                                                  7
# 1                                                  7
# 2                                                  7
# 3                                                  1
# 4                                                  1
#
#            shape1            shape2
# 0  high convexity    high convexity
# 1  high convexity    high convexity
# 2  high convexity    high convexity
# 3  high convexity  thin rectangular
# 4  high convexity  thin rectangular

# %%
shape_dataset = shape_dataset.rename(columns={"on_a_scale_of_1_to_7_how_much_shape1_is_similar_to_shape2__with_7_being_the_highest_level_of_similarity":"similarity"})

# %%
shape_dataset.head()
# Out:
#    similarity          shape1            shape2
# 0           7  high convexity    high convexity
# 1           7  high convexity    high convexity
# 2           7  high convexity    high convexity
# 3           1  high convexity  thin rectangular
# 4           1  high convexity  thin rectangular
